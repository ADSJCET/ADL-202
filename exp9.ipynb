# %%
import matplotlib.pyplot as plt

x = range(0,7+1)
y = []
fx = lambda x: x ** 4 + 5

for i in x:
    y.append(fx(i))
    
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y = f (x)")

plt.show()
